# %%
# !git clone https://github.com/IlyaGusev/UNMT

# %% [markdown]
# # import drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd gdrive/My\ Drive/Colab Notebooks/495/unmt_Test
# Out:
# /content/gdrive/My Drive/Colab Notebooks/495/unmt_Test

# %%
# !ls -lh
# Out:
# total 28K
# drwx------ 4 root root 4.0K Aug 24 11:23 data
# -rw------- 1 root root  297 Aug 24 12:09 pred.txt
# drwx------ 2 root root 4.0K Aug 24 11:42 pretrain_model
# drwx------ 3 root root 4.0K Aug 24 11:23 src
# drwx------ 2 root root 4.0K Aug 24 11:23 tests
# -rw------- 1 root root 3.2K Aug 24 12:13 test_unmt.ipynb
# -rw------- 1 root root 3.6K Aug 24 12:04 translate_us.py
# drwx------ 3 root root 4.0K Aug 24 11:23 utils

# %% [markdown]
# # Test

# %%
# !python translate_us.py -s 'data/test/en_test_01.txt' -sl e -t 'pred.txt'
# Out:
# INFO:root:Use CUDA: True
# INFO:root:Collecting vocabulary...
# INFO:root:Writing output...
# DEBUG:root:<unk> <unk> তুই
# DEBUG:root:<unk> <unk> জরিমানা
# DEBUG:root:<unk> খাবে ভাত
# DEBUG:root:<unk> <unk> অনেকটা
# DEBUG:root:<unk> <unk> <unk>
# DEBUG:root:<unk> <unk> তুমি ভাবুন
# DEBUG:root:<unk> সাউন্ড দারুন
# DEBUG:root:<unk> <unk>
# DEBUG:root:<unk> <unk> না বুঝে
# DEBUG:root:<unk> <unk> <unk> আপনাকে

# %%
# !python translate_us.py -s 'data/test/bn_test_01.txt' -sl b -t 'pred.txt'
# Out:
# INFO:root:Use CUDA: True
# INFO:root:Collecting vocabulary...
# INFO:root:Writing output...
# DEBUG:root:how <unk>
# DEBUG:root:me well
# DEBUG:root:me rice eat
# DEBUG:root:thanks
# DEBUG:root:sorry
# DEBUG:root:what <unk>
# DEBUG:root:well matter
# DEBUG:root:few no
# DEBUG:root:me <unk>
# DEBUG:root:seeing <unk> good <unk>
